# %%
## list ####
#Definicion

my_list=list()
my_other_list=[]

my_other_list=[]
print(len(my_list))
my_list=[35, 24, 62, 52, 30, 30, 17]
print(my_list)
print(len(my_list))

my_other_list=[35, 1.77, "Fermin", "Garcia"]
print(type(my_list))
print(type(my_other_list))

#Acceso a elementos y busqueda

print(my_other_list[0])
print(my_other_list[1])
print(my_other_list[-1])
print(my_other_list[-4])
print(my_list.count(30))
#print(my_other_list[4]) IndexError
#print(my_other_list[-5])

print(my_other_list.index("Fermin"))

age, height, name, surname = my_other_list
print(name)

name, height, name, surname = my_other_list[2], my_other_list[1], my_other_list[0], my_other_list[3]

#Concatenación
print(my_list + my_other_list)
#print(my_other_list)

#Creacion, insecion, actualizacion y eliminacion

my_other_list.append("CECyTEM")#agrega uno al final
print(my_other_list)

my_other_list.insert(1, "Rojo")#agrega en esa posicion
print(my_other_list)

my_other_list[1]="Azul"#cambi lo que hay en esa posicion
print(my_other_list)

my_other_list.remove("Azul")
print(my_other_list)

my_list.remove(30)
print(my_list)

print(my_list.pop())#muestra el ultimo elemento eliminado
print(my_list)

my_pop_element = my_list.pop(2)
print(my_pop_element)
print(my_list)

del my_list[2]
print(my_list)

#Operciones con listas

my_new_list = my_list.copy()

my_list.clear()
print(my_list)
print(my_new_list)

my_new_list.reverse()
print(my_new_list)

my_new_list.sort()
print(my_new_list)


#Sublistas

print(my_new_list[1:3])

#Cambio de tipo
my_list = "Hola python"
print(my_list)
print(type(my_list))
# Out:
# 0
# [35, 24, 62, 52, 30, 30, 17]
# 7
# <class 'list'>
# <class 'list'>
# 35
# 1.77
# Garcia
# 35
# 2
# 2
# Fermin
# [35, 24, 62, 52, 30, 30, 17, 35, 1.77, 'Fermin', 'Garcia']
# [35, 1.77, 'Fermin', 'Garcia', 'CECyTEM']
# [35, 'Rojo', 1.77, 'Fermin', 'Garcia', 'CECyTEM']
# [35, 'Azul', 1.77, 'Fermin', 'Garcia', 'CECyTEM']
# [35, 1.77, 'Fermin', 'Garcia', 'CECyTEM']
# [35, 24, 62, 52, 30, 17]
# 17
# [35, 24, 62, 52, 30]
# 62
# [35, 24, 52, 30]
# [35, 24, 30]
# []
# [35, 24, 30]
# [30, 24, 35]
# [24, 30, 35]
# [30, 35]
# Hola python
# <class 'str'>
