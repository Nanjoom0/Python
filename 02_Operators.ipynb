# %%
### Operadores Aricmeticos ###
#Operadores con enteros
#print(3+4)
#print(3*4)
#print(3/4)
#print(10%3)
#print(10//3)
#print(2**3)
#print(2**3+3-7/1//4)

#Operadores con enteros
#print(3>4)
#print(3<4)
#print(3>=4)
#print(3<=4)
#print(3==4)
#print(3!=4)

#Operaciones con cadena de texto
#"""print("Hola" >"python")
#print("Hola" < "Python")
#print("aaaa" >="aba")#Operacion algebraica por ASCII
#print(len("aaaa")>=len("abaa"))#cuenta carecteres
#print("Hola"<="Python")
#print("Hola"=="Python")
#print("Hola" !="Python")

###Operadores Lógicos###
#Basada en algebra de Boole
print(3>4 and"Hola">"Python")
print(3>4 or "Hola" >"Python")
print(3<4 and "Hola"<"Python")
print(3<4 or "Hola"< "Python")
print(3<4  or ("Hola"<"Python" and 4==4))
print(not (3>4))
# Out:
# False
# False
# True
# True
# True
# True
