# %%
### variables ###

my_string_variable="My string variable"
#print(my_string_variable)

#my_int_variable = 5
#print(my_variable)

#mi_int_to_str_variable=str(my_int_variable)
print(type(my_int_to_str_variable))

#my_bool_variable=false
#print_bool_variable



#concatenacion de variables print
#print(my_string_variable, my_int_to_str_variable, my_bool_variable)
#print("Este es el valor de:", my_bool_variable)

#Algunas funciones del sistema
#print(len(my_string_variable))

#Variables en un sola linea. ¡Cuidado con abusan de la sintaxis!
#name, surname, alias, age ="Grupo", "programacion", 'CECyTEM', 35
#print("Me llamo:", name, surname," . Mi edad es:",
 #     age,".y el alias es:", alias)


#Input
#name = input('¿Cual es tu nombre?')
#age = input('¿Cuantos años tienes?')
#print(name)
#print(age)


#Cambiamos su tipo
#name = 23
#age = "Carlos"
#print(name)
#print(age)

#¿Forzamos el tipo?
address: str = "Mi direccion"
address = True
address = 5
address = 1.2
print(type(address))
# Out:
#   File "<ipython-input-13-bd8775ffcca0>", line 45
#     address str = "Mi direccion"
#             ^
# SyntaxError: invalid syntax
