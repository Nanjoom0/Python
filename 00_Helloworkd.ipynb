# %%
#Esto es un comentario
print(variable)
# Out:
# hola mundo🐔🐋

# %%
variable = "hola mundo🐔🐋"

#este simbolo se utiliza para comentar el codigo
#print("Hola Grupo 430 de la carrera de programación")



#como consultar el tipo de dato
#print(type("Soy un dato str"))#Tipo cadena
#print(type("5"))#Tipo 'int'
#print(type("1,5"))#Tipo 'float'
#print(type("3+1j"))#Tipo 'complex'
#print(type("True"))#Tipo 'bool'
#print(type(print("Mi cadena de texto")))#Tipo 'NomeType'
# Out:
# Hola Grupo 430 de la carrera de programación
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# Mi cadena de texto
# <class 'NoneType'>
