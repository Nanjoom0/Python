# %%
###Tuples###

#Definicion

my_tuple = tuple()
my_other_tuple = ()

my_tuple = (35, 1.77, "Fermin", "Garcia", "profesor")
my_other_tuple = (35, 60, 30)

print(my_tuple)
print(type(my_tuple))

#Acceo a elementos y busqueda

print(my_tuple[0])
print(my_tuple[-1])
#print(my_tuples[5]) #IndexError
#print(my_tuples[6])#I
